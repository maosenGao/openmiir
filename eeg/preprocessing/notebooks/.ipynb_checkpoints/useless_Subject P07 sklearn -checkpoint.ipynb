# %%
"""
General workflow for importing a new session
"""
subject = 'P07' # TODO: change this for each subject
verbose = True  # change this for debugging

import matplotlib
# %matplotlib inline


from deepthought.datasets.openmiir.preprocessing.pipeline import Pipeline # Previous job
from sklearn.pipeline import Pipeline

settings = dict(debug=False,
                mne_log_level='Info',
                sfreq=64) # optional pipeline settings

pipeline = Pipeline(subject, settings)

# pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC())])
# Out:
# d:\anacon\envs\python27\lib\site-packages\librosa\__init__.py:35: FutureWarning: You are using librosa with Python 2. Please note that librosa 0.7 will be the last version to support Python 2, after which it will require Python 3 or later.
#   FutureWarning)

# %% [markdown]
# # Import or Load Raw

# %%
pipeline.import_and_process_metadata(verbose=verbose)
# 这句话本来没有被注释掉，是高茂森注释掉的
# Out:
# Skipping existing E:\OpenMIIR-RawEEG_v1\OpenMIIR\eeg\mne\P07-raw.fif

# %%
# IOError: [Errno 2] No such file or directory: 'E:\\OpenMIIR-RawEEG_v1\\OpenMIIR\\eeg\\biosemi\\P07.bdf'
pipeline.load_raw(verbose=verbose)
# [Errno 2] No such file or directory: 'E:\\OpenMIIR-RawEEG_v1\\OpenMIIR\\eeg\\mne\\P07-raw.fif'
# Out:
# Loading raw data for subject "P07" from E:\OpenMIIR-RawEEG_v1\OpenMIIR\eeg\mne\P07-raw.fif
# Opening raw data file E:\OpenMIIR-RawEEG_v1\OpenMIIR\eeg\mne\P07-raw.fif...
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:178: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(tag_size), dtype=dtype)
# Isotrak not found
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:363: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   version=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:364: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   machid=np.fromstring(fid.read(8), dtype=">i4"),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:365: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   secs=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:366: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   usecs=int(np.fromstring(fid.read(4), dtype=">i4")))
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:178: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(tag_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:363: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   version=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:364: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   machid=np.fromstring(fid.read(8), dtype=">i4"),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:365: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   secs=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:366: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   usecs=int(np.fromstring(fid.read(4), dtype=">i4")))
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:363: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   version=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:364: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   machid=np.fromstring(fid.read(8), dtype=">i4"),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:365: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   secs=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:366: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   usecs=int(np.fromstring(fid.read(4), dtype=">i4")))
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:178: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(tag_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:178: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(tag_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:178: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(tag_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:178: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(tag_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:178: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(tag_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:178: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(tag_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:178: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(tag_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:178: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(tag_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:178: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(tag_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:178: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(tag_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:178: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(tag_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:178: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(tag_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:178: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(tag_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:178: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(tag_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:402: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   scanno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:403: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   logno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:404: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   kind=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:405: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   range=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:406: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   cal=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:407: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   coil_type=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:409: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   loc=np.fromstring(fid.read(48), dtype=">f4").astype(np.float64),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:411: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:412: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit_mul=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:415: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   ch_name = np.fromstring(fid.read(16), dtype=">c")
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:402: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   scanno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:403: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   logno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:404: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   kind=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:405: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   range=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:406: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   cal=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:407: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   coil_type=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:409: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   loc=np.fromstring(fid.read(48), dtype=">f4").astype(np.float64),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:411: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:412: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit_mul=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:415: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   ch_name = np.fromstring(fid.read(16), dtype=">c")
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:402: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   scanno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:403: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   logno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:404: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   kind=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:405: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   range=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:406: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   cal=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:407: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   coil_type=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:409: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   loc=np.fromstring(fid.read(48), dtype=">f4").astype(np.float64),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:411: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:412: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit_mul=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:415: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   ch_name = np.fromstring(fid.read(16), dtype=">c")
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:402: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   scanno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:403: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   logno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:404: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   kind=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:405: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   range=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:406: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   cal=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:407: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   coil_type=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:409: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   loc=np.fromstring(fid.read(48), dtype=">f4").astype(np.float64),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:411: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:412: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit_mul=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:415: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   ch_name = np.fromstring(fid.read(16), dtype=">c")
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:402: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   scanno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:403: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   logno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:404: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   kind=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:405: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   range=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:406: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   cal=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:407: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   coil_type=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:409: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   loc=np.fromstring(fid.read(48), dtype=">f4").astype(np.float64),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:411: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:412: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit_mul=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:415: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   ch_name = np.fromstring(fid.read(16), dtype=">c")
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:402: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   scanno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:403: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   logno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:404: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   kind=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:405: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   range=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:406: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   cal=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:407: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   coil_type=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:409: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   loc=np.fromstring(fid.read(48), dtype=">f4").astype(np.float64),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:411: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:412: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit_mul=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:415: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   ch_name = np.fromstring(fid.read(16), dtype=">c")
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:402: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   scanno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:403: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   logno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:404: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   kind=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:405: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   range=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:406: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   cal=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:407: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   coil_type=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:409: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   loc=np.fromstring(fid.read(48), dtype=">f4").astype(np.float64),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:411: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:412: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit_mul=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:415: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   ch_name = np.fromstring(fid.read(16), dtype=">c")
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:402: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   scanno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:403: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   logno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:404: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   kind=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:405: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   range=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:406: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   cal=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:407: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   coil_type=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:409: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   loc=np.fromstring(fid.read(48), dtype=">f4").astype(np.float64),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:411: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:412: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit_mul=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:415: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   ch_name = np.fromstring(fid.read(16), dtype=">c")
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:402: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   scanno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:403: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   logno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:404: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   kind=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:405: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   range=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:406: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   cal=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:407: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   coil_type=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:409: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   loc=np.fromstring(fid.read(48), dtype=">f4").astype(np.float64),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:411: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:412: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit_mul=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:415: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   ch_name = np.fromstring(fid.read(16), dtype=">c")
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:402: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   scanno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:403: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   logno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:404: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   kind=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:405: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   range=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:406: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   cal=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:407: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   coil_type=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:409: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   loc=np.fromstring(fid.read(48), dtype=">f4").astype(np.float64),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:411: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:412: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit_mul=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:415: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   ch_name = np.fromstring(fid.read(16), dtype=">c")
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:402: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   scanno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:403: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   logno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:404: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   kind=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:405: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   range=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:406: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   cal=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:407: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   coil_type=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:409: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   loc=np.fromstring(fid.read(48), dtype=">f4").astype(np.float64),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:411: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:412: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit_mul=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:415: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   ch_name = np.fromstring(fid.read(16), dtype=">c")
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:402: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   scanno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:403: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   logno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:404: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   kind=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:405: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   range=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:406: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   cal=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:407: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   coil_type=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:409: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   loc=np.fromstring(fid.read(48), dtype=">f4").astype(np.float64),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:411: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:412: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit_mul=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:415: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   ch_name = np.fromstring(fid.read(16), dtype=">c")
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:402: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   scanno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:403: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   logno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:404: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   kind=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:405: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   range=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:406: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   cal=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:407: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   coil_type=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:409: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   loc=np.fromstring(fid.read(48), dtype=">f4").astype(np.float64),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:411: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:412: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit_mul=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:415: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   ch_name = np.fromstring(fid.read(16), dtype=">c")
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:402: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   scanno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:403: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   logno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:404: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   kind=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:405: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   range=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:406: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   cal=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:407: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   coil_type=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:409: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   loc=np.fromstring(fid.read(48), dtype=">f4").astype(np.float64),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:411: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:412: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit_mul=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:415: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   ch_name = np.fromstring(fid.read(16), dtype=">c")
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:402: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   scanno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:403: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   logno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:404: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   kind=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:405: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   range=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:406: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   cal=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:407: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   coil_type=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:409: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   loc=np.fromstring(fid.read(48), dtype=">f4").astype(np.float64),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:411: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:412: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit_mul=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:415: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   ch_name = np.fromstring(fid.read(16), dtype=">c")
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:402: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   scanno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:403: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   logno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:404: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   kind=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:405: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   range=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:406: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   cal=float(np.fromstring(fid.read(4), dtype=">f4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:407: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   coil_type=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:409: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   loc=np.fromstring(fid.read(48), dtype=">f4").astype(np.float64),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:411: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:412: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   unit_mul=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:415: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   ch_name = np.fromstring(fid.read(16), dtype=">c")
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:402: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   scanno=int(np.fromstring(fid.read(4), dtype=">i4")),
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:403: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   logno=int(np.fromstring(fid.read(4), dtype=">i4")),
# ...
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# Referencing to average.
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# d:\anacon\envs\python27\lib\site-packages\mne\io\tag.py:174: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   out = np.fromstring(fid.read(read_size), dtype=dtype)
# The behavior of set_eeg_reference will change in 0.16 when ref_channels="average". Currently, a projection is computed, which has to be applied manually with the apply_proj method. In 0.16, the average reference will be directly applied. Set projection=True if you want to retain the old behavior, or set projection=False if you want the new behavior.
# An average reference projection was already added. The data has been left untouched.
# deepthought\datasets\openmiir\preprocessing\pipeline.py:94: DeprecationWarning: The behavior of set_eeg_reference will change in 0.16 when ref_channels="average". Currently, a projection is computed, which has to be applied manually with the apply_proj method. In 0.16, the average reference will be directly applied. Set projection=True if you want to retain the old behavior, or set projection=False if you want the new behavior.
#   mne.io.set_eeg_reference(raw, copy=False)
# deepthought\datasets\openmiir\preprocessing\pipeline.py:94: RuntimeWarning: An average reference projection was already added. The data has been left untouched.
#   mne.io.set_eeg_reference(raw, copy=False)

# %%
print pipeline.raw.info
# Out:
# <Info | 18 non-empty fields
#     bads : list | 0 items
#     buffer_size_sec : float64 | 10.0
#     ch_names : list | Fp1, AF7, AF3, F1, F3, F5, F7, FT7, FC5, ...
#     chs : list | 69 items (EEG: 64, STIM: 1, EOG: 4)
#     comps : list | 0 items
#     custom_ref_applied : bool | False
#     events : list | 0 items
#     file_id : dict | 4 items
#     highpass : float | 0.0 Hz
#     hpi_meas : list | 0 items
#     hpi_results : list | 0 items
#     lowpass : float | 417.0 Hz
#     meas_date : ndarray | 2015-02-12 10:49:08 GMT
#     meas_id : dict | 4 items
#     nchan : int | 69
#     proc_history : list | 0 items
#     projs : list | Average EEG reference: off
#     sfreq : float | 512.0 Hz
#     acq_pars : NoneType
#     acq_stim : NoneType
#     ctf_head_t : NoneType
#     description : NoneType
#     dev_ctf_t : NoneType
#     dev_head_t : NoneType
#     dig : NoneType
#     experimenter : NoneType
#     hpi_subsystem : NoneType
#     kit_system_id : NoneType
#     line_freq : NoneType
#     proj_id : NoneType
#     proj_name : NoneType
#     subject_info : NoneType
#     xplotter_layout : NoneType
# >

# %% [markdown]
# # Reject Bad Channels

# %%
# switch to interactive GUI mode to scroll through data
# %matplotlib tk 
pipeline.plot_raw();
pass
# Out:
# scroll using cursor keys, click on channels to mark as "bad"

# %%
# switch back to inline mode
# %matplotlib inline

# %%
# pipeline.reset_bad_channels() # use this to reset the channel list if needed

# %%
# TODO: change these value manually
# If you would rather apply the bandpass filter first, continue until it is applied 
# and then come back to this cell
pipeline.mark_bad_channels(None, save_to_raw=False) # nothing to change, None will keep old values
# pipeline.mark_bad_channels(['P8', 'P10', 'T8'], save_to_raw=True)
# Out:
# ('The following channels have been marked as bad:', [])

# %%
pipeline.print_bad_channels()
# Out:
# ('bad channels:', [])

# %%
pipeline.interpolate_bad_channels() # Note: this will overwrite data
# Out:
# No bad channels that need to be interpolated.

# %% [markdown]
# # Check and Merge Trials

# %%
pipeline.check_trial_events()
# Out:
# 540 events found
# Events id: [  11   12   13   14   21   22   23   24   31   32   33   34   41   42
#    43   44  111  112  113  114  121  122  123  124  131  132  133  134
#   141  142  143  144  211  212  213  214  221  222  223  224  231  232
#   233  234  241  242  243  244 1000 1111 2000 2001]
# More events than colors available. You should pass a list of unique colors.
# deepthought\datasets\openmiir\preprocessing\pipeline.py:454: RuntimeWarning: More events than colors available. You should pass a list of unique colors.
#   mne.viz.plot_events(trial_events, raw.info['sfreq'], raw.first_samp, axes=axes)
# ('1st event at ', 1.0)
# ('last event at ', 4902.7265625)

# %%
pipeline.check_trial_audio_onset_merge(use_audio_onsets=True, 
                                       verbose=None)
# Out:
# 540 events found
# Events id: [  11   12   13   14   21   22   23   24   31   32   33   34   41   42
#    43   44  111  112  113  114  121  122  123  124  131  132  133  134
#   141  142  143  144  211  212  213  214  221  222  223  224  231  232
#   233  234  241  242  243  244 1000 1111 2000 2001]
# More events than colors available. You should pass a list of unique colors.
# deepthought\datasets\openmiir\preprocessing\pipeline.py:477: RuntimeWarning: More events than colors available. You should pass a list of unique colors.
#   mne.viz.plot_events(merged_events, raw.info['sfreq'], raw.first_samp, axes=axes)

# %%
pipeline.merge_trial_and_audio_onsets()
# Out:
# 540 events found
# Events id: [  11   12   13   14   21   22   23   24   31   32   33   34   41   42
#    43   44  111  112  113  114  121  122  123  124  131  132  133  134
#   141  142  143  144  211  212  213  214  221  222  223  224  231  232
#   233  234  241  242  243  244 1000 1111 2000 2001]
# 360 events found
# Events id: [  11   12   13   14   21   22   23   24   31   32   33   34   41   42
#    43   44  111  112  113  114  121  122  123  124  131  132  133  134
#   141  142  143  144  211  212  213  214  221  222  223  224  231  232
#   233  234  241  242  243  244 1111 2000 2001]

# %% [markdown]
# # Check PSD and Channels

# %%
pipeline.check_psd()
pipeline.check_psd(fmax=35)
# line noise will probably be visible @ multiples of 60Hz
# Out:
# Effective window size : 4.000 (s)
# d:\anacon\envs\python27\lib\site-packages\mne\viz\raw.py:719: DeprecationWarning: In version 0.15 average will default to False and spatial_colors will default to True.
#   'spatial_colors will default to True.', DeprecationWarning)
# Effective window size : 4.000 (s)
# d:\anacon\envs\python27\lib\site-packages\mne\viz\raw.py:719: DeprecationWarning: In version 0.15 average will default to False and spatial_colors will default to True.
#   'spatial_colors will default to True.', DeprecationWarning)

# %%
pipeline.check_channel(0)
# quite some drift and movement in the breaks
# Out:
# (2520437L,)

# %% [markdown]
# # Bandpass Filtering

# %%
pipeline.bandpass_filter()
# Out:
# Setting up band-pass filter from 0.5 - 30 Hz
# fir_design defaults to "firwin2" in 0.15 but will change to "firwin" in 0.16, set it explicitly to avoid this warning.
# Attenuation at stop frequency 0.4Hz is only 11.6dB. Increase filter_length for higher attenuation.
# deepthought\datasets\openmiir\preprocessing\pipeline.py:558: DeprecationWarning: fir_design defaults to "firwin2" in 0.15 but will change to "firwin" in 0.16, set it explicitly to avoid this warning.
#   n_jobs=4, verbose=True)
# deepthought\datasets\openmiir\preprocessing\pipeline.py:558: RuntimeWarning: Attenuation at stop frequency 0.4Hz is only 11.6dB. Increase filter_length for higher attenuation.
#   n_jobs=4, verbose=True)
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=4)]: Done  64 out of  64 | elapsed:   17.7s finished

# %%
# %matplotlib tk 
pipeline.plot_raw();
pass
# Out:
# scroll using cursor keys, click on channels to mark as "bad"

# %%
# %matplotlib inline

# %%
pipeline.check_channel(0)
# looks like we got rid of that drift - nice!
# what's that? eyeblinks?
# Out:
# (2520437L,)

# %%
## check PSD again - after bandpass, before down-sampling
pipeline.check_psd()
pipeline.check_psd(fmax=35)
# 60Hz is still visible
# Out:
# Effective window size : 4.000 (s)
# d:\anacon\envs\python27\lib\site-packages\mne\viz\raw.py:719: DeprecationWarning: In version 0.15 average will default to False and spatial_colors will default to True.
#   'spatial_colors will default to True.', DeprecationWarning)
# Effective window size : 4.000 (s)
# d:\anacon\envs\python27\lib\site-packages\mne\viz\raw.py:719: DeprecationWarning: In version 0.15 average will default to False and spatial_colors will default to True.
#   'spatial_colors will default to True.', DeprecationWarning)

# %% [markdown]
# # Beat and EOG Epoching

# %%
pipeline.generate_beat_events() # Note: this includes cue-beats !!!
pipeline.beat_epochs.average().plot();
# Out:
# <Epochs  |  n_events : 8140 (all good), tmin : -0.19921875 (s), tmax : 0.80078125 (s), baseline : (None, 0), ~2.15 GB, data loaded>

# %%
pipeline.find_eog_events()
# wow - that's a lot of blinking
# Out:
# EOG channel index for this subject is: [64 65 66 67]
# Filtering the data to remove DC offset to help distinguish blinks from saccades
# Setting up band-pass filter from 2 - 45 Hz
# Setting up band-pass filter from 2 - 45 Hz
# Setting up band-pass filter from 2 - 45 Hz
# Setting up band-pass filter from 2 - 45 Hz
# Setting up band-pass filter from 1 - 10 Hz
# Now detecting blinks and generating corresponding events
# Number of EOG events detected : 684

# %% [markdown]
# # Down-Sampling

# %%
pipeline.downsample()
# Out:
# ()
# down-sampling raw and events stim channel ...
# Saving events for stim channel "STI 014" (#68)
# 360 events found
# Events id: [  11   12   13   14   21   22   23   24   31   32   33   34   41   42
#    43   44  111  112  113  114  121  122  123  124  131  132  133  134
#   141  142  143  144  211  212  213  214  221  222  223  224  231  232
#   233  234  241  242  243  244 1111 2000 2001]
# Resampling 69 channels from 512.0 Hz to 64.0 Hz ...
# Processing channel #0
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-23-edaaf6af5191> in <module>()
# ----> 1 pipeline.downsample()
#
# E:\360MoveData\Users\zx305\Documents\GitHub\openmiir\eeg\preprocessing\notebooks\deepthought\datasets\openmiir\preprocessing\pipeline.pyc in downsample(self)
#     649
#     650         print( 'down-sampling raw and events stim channel ...')
# --> 651         fast_resample_mne(raw, sfreq, res_type='sinc_best', preserve_events=True, verbose=True)
#     652         # fast_resample_mne(raw, sfreq, res_type='sinc_fastest', preserve_events=True, verbose=False)
#     653
#
# E:\360MoveData\Users\zx305\Documents\GitHub\openmiir\eeg\preprocessing\notebooks\deepthought\mneext\resample.pyc in fast_resample_mne(raw, sfreq, stim_picks, preserve_events, res_type, verbose)
#      93                 log.info('Processing channel #{}'.format(i))
#      94             # TODO: this could easily be parallelized
# ---> 95             new_data_chunk.append(librosa.resample(channel, o_sfreq, sfreq, res_type=res_type))
#      96
#      97         new_data_chunk = np.vstack(new_data_chunk)
#
# d:\anacon\envs\python27\lib\site-packages\librosa\core\audio.pyc in resample(y, orig_sr, target_sr, res_type, fix, scale, **kwargs)
#     545         y_hat = scipy.signal.resample_poly(y, target_sr // gcd, orig_sr // gcd, axis=-1)
#     546     else:
# --> 547         y_hat = resampy.resample(y, orig_sr, target_sr, filter=res_type, axis=-1)
#     548
#     549     if fix:
#
# d:\anacon\envs\python27\lib\site-packages\resampy\core.pyc in resample(x, sr_orig, sr_new, axis, filter, **kwargs)
#     107     y = np.zeros(shape, dtype=x.dtype, order=order)
#     108
# --> 109     interp_win, precision, _ = get_filter(filter, **kwargs)
#     110
#     111     if sample_ratio < 1:
#
# d:\anacon\envs\python27\lib\site-packages\resampy\filters.pyc in get_filter(name_or_function, **kwargs)
#     165         except (IOError, ValueError):
#     166             raise NotImplementedError('Cannot load filter definition for '
# --> 167                                       '{}'.format(name_or_function))
#     168
#     169
#
# NotImplementedError: Cannot load filter definition for sinc_best

# %%
## PSD after down-sampling:
pipeline.check_psd(fmax=35)
# looks less smooth than without down-sampling

# %%
# check events after after resampling -> should get the same result as above
pipeline.check_resampled_trial_events(plot=True, verbose=False)

# %% [markdown]
# # ICA

# %%
pipeline.compute_ica(verbose=True)

# %%
# %matplotlib inline
pipeline.plot_ica_components() # static plot

# %%
pipeline.inspect_source_psd(1) # plot the PSD of an IC source to look for alpha activity
pipeline.inspect_source_psd(2)

# %%
pipeline.find_eog_artifact_sources(plot=True, verbose=False)

# %%
pipeline.auto_detect_artifact_components()

# %%
pipeline.select_artifact_sources(selection='auto')

# %%
pipeline.exclude_ica_components(selection=[0, 2]) # TODO: adapt selection list
# use cells below to decide, which components to reject, then come back to this cell

# %%
for ic in pipeline.suggested_artifact_components:
# for ic in pipeline.ica.exclude:
    pipeline.inspect_ica_component(ic, [0, 700])
    pipeline.inspect_source_epochs(ic, mode='beats', vmax=5)
    pipeline.inspect_source_epochs(ic, mode='eog', vmax=5)

# %%
# enable this for interactive mode
# %matplotlib tk

# pipeline.plot_sources(mode='raw')   # this may take a while
# pipeline.plot_sources(mode='beats')
pipeline.plot_sources(mode='eog');

# %%
# switch back to non-interactive inline mode
# %matplotlib inline

# %%
pipeline.assess_unmixing_quality(verbose=False)

# %%
pipeline.save_ica('100p_64c') # save for later

# %% [markdown]
# # Application Test

# %%
pipeline.load_ica('100p_64c')

# %%
raw = pipeline.ica.apply(pipeline.raw, exclude=(pipeline.ica.exclude), copy=False)
if len(raw.info['bads']) > 0:
    raw.interpolate_bads_eeg() # interpolate bad channels afterwards as they are not processed by the ICA

# %matplotlib tk 
pipeline.plot_raw();
pass
