# %%
"""
General workflow for importing a new session
"""
subject = 'P09' # TODO: change this for each subject
verbose = True  # change this for debugging

import matplotlib
# %matplotlib inline

from deepthought.datasets.openmiir.preprocessing.pipeline import Pipeline
settings = dict(debug=False, mne_log_level='Info', sfreq=64) # optional pipeline settings
pipeline = Pipeline(subject, settings)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\360movedata\users\zx305\documents\github\pylearn2\utils\string_utils.py in preprocess(string, environ)
#      52             val = (environ[varname] if varname in environ
# ---> 53                    else os.environ[varname])
#      54         except KeyError:
#
# ~\.conda\envs\python37\lib\os.py in __getitem__(self, key)
#     678             # raise KeyError with the original key value
# --> 679             raise KeyError(key) from None
#     680         return self.decodevalue(value)
#
# KeyError: 'DEEPTHOUGHT_OUTPUT_PATH'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-31989f1c0810> in <module>
#       8 get_ipython().run_line_magic('matplotlib', 'inline')
#       9
# ---> 10 from deepthought.datasets.openmiir.preprocessing.pipeline import Pipeline
#      11 settings = dict(debug=False, mne_log_level='Info', sfreq=64) # optional pipeline settings
#      12 pipeline = Pipeline(subject, settings)
#
# E:\360MoveData\Users\zx305\Documents\GitHub\openmiir\eeg\preprocessing\notebooks\deepthought\__init__.py in <module>
#      11 # and make them available at top-level namespace
#      12 DATA_PATH = preprocess('${DEEPTHOUGHT_DATA_PATH}')
# ---> 13 OUTPUT_PATH = preprocess('${DEEPTHOUGHT_OUTPUT_PATH}')
#      14
#      15 # Remove this from the top-level namespace.
#
# E:\360movedata\users\zx305\documents\github\pylearn2\utils\string_utils.py in preprocess(string, environ)
#      62             reraise_as(ValueError('Unrecognized environment variable "' +
#      63                                   varname + '". Did you mean ' +
# ---> 64                                   match(varname, os.environ.keys()) + '?'))
#      65
#      66         rval.append(val)
#
# E:\360movedata\users\zx305\documents\github\pylearn2\utils\exc.py in reraise_as(new_exc)
#      88     new_exc.__cause__ = orig_exc_value
#      89     new_exc.reraised = True
# ---> 90     six.reraise(type(new_exc), new_exc, orig_exc_traceback)
#
# ~\.conda\envs\python37\lib\site-packages\theano\compat\six.py in reraise(tp, value, tb)
#     657             value = tp()
#     658         if value.__traceback__ is not tb:
# --> 659             raise value.with_traceback(tb)
#     660         raise value
#     661
#
# E:\360movedata\users\zx305\documents\github\pylearn2\utils\string_utils.py in preprocess(string, environ)
#      51         try:
#      52             val = (environ[varname] if varname in environ
# ---> 53                    else os.environ[varname])
#      54         except KeyError:
#      55             if varname == 'PYLEARN2_DATA_PATH':
#
# ~\.conda\envs\python37\lib\os.py in __getitem__(self, key)
#     677         except KeyError:
#     678             # raise KeyError with the original key value
# --> 679             raise KeyError(key) from None
#     680         return self.decodevalue(value)
#     681
#
# ValueError: Unrecognized environment variable "DEEPTHOUGHT_OUTPUT_PATH". Did you mean DEEPTHOUGHT_DATA_PATH?
#
# Original exception:
# 	KeyError: DEEPTHOUGHT_OUTPUT_PATH

# %%
# !pip install theano==0.9.0 -i https://pypi.douban.com/simple
    
print(theano.__path__)
# Out:
# Looking in indexes: https://pypi.douban.com/simple
# Requirement already satisfied: theano==0.9.0 in c:\users\zx305\.conda\envs\python37\lib\site-packages (0.9.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\zx305\appdata\roaming\python\python37\site-packages (from theano==0.9.0) (1.12.0)
# Requirement already satisfied: scipy>=0.14 in c:\users\zx305\.conda\envs\python37\lib\site-packages (from theano==0.9.0) (1.4.1)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\zx305\.conda\envs\python37\lib\site-packages (from theano==0.9.0) (1.18.1)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-51440158a650> in <module>
#       1 get_ipython().system('pip install theano==0.9.0 -i https://pypi.douban.com/simple')
#       2
# ----> 3 print(theano.__path__)
#
# NameError: name 'theano' is not defined

# %% [markdown]
# # Import or Load Raw

# %%
pipeline.import_and_process_metadata(verbose=verbose)
pipeline.load_raw(verbose=verbose)
# Out:
# Importing raw BDF data from: /imaging/deepthought/datasets/mpi2015/eeg/biosemi/P09.bdf
# Extracting edf Parameters from /imaging/deepthought/datasets/mpi2015/eeg/biosemi/P09.bdf...
# Setting channel info structure...
# Creating Raw.info structure...
# Reading raw data from /imaging/deepthought/datasets/mpi2015/eeg/biosemi/P09.bdf...
# Reading 0 ... 2544639  =      0.000 ...  4969.998 secs...
# [done]
#     Range : 0 ... 2544639 =      0.000 ...  4969.998 secs
# Ready.
# Imported raw data: <RawEDF  |  'P09.bdf', n_channels x n_times : 80 x 2544640>
# Marked unused channels as bad: [u'C1', u'C2', u'C3', u'C4', u'C5', u'C6', u'C7', u'C8', u'C9', u'C10', u'C11', u'C12', u'C13', u'C14', u'C15', u'C16', u'C17', u'C18', u'C19', u'C20', u'C21', u'C22', u'C23', u'C24', u'C25', u'C26', u'C27', u'C28', u'C29', u'C30', u'C31', u'C32', u'D1', u'D2', u'D3', u'D4', u'D5', u'D6', u'D7', u'D8', u'D9', u'D10', u'D11', u'D12', u'D13', u'D14', u'D15', u'D16', u'D17', u'D18', u'D19', u'D20', u'D21', u'D22', u'D23', u'D24', u'D25', u'D26', u'D27', u'D28', u'D29', u'D30', u'D31', u'D32', u'E1', u'E2', u'E3', u'E4', u'E5', u'E6', u'E7', u'E8', u'E9', u'E10', u'E11', u'E12', u'E13', u'E14', u'E15', u'E16', u'E17', u'E18', u'E19', u'E20', u'E21', u'E22', u'E23', u'E24', u'E25', u'E26', u'E27', u'E28', u'E29', u'E30', u'E31', u'E32', u'F1', u'F2', u'F3', u'F4', u'F5', u'F6', u'F7', u'F8', u'F9', u'F10', u'F11', u'F12', u'F13', u'F14', u'F15', u'F16', u'F17', u'F18', u'F19', u'F20', u'F21', u'F22', u'F23', u'F24', u'F25', u'F26', u'F27', u'F28', u'F29', u'F30', u'F31', u'F32', u'G1', u'G2', u'G3', u'G4', u'G5', u'G6', u'G7', u'G8', u'G9', u'G10', u'G11', u'G12', u'G13', u'G14', u'G15', u'G16', u'G17', u'G18', u'G19', u'G20', u'G21', u'G22', u'G23', u'G24', u'G25', u'G26', u'G27', u'G28', u'G29', u'G30', u'G31', u'G32', u'H1', u'H2', u'H3', u'H4', u'H5', u'H6', u'H7', u'H8', u'H9', u'H10', u'H11', u'H12', u'H13', u'H14', u'H15', u'H16', u'H17', u'H18', u'H19', u'H20', u'H21', u'H22', u'H23', u'H24', u'H25', u'H26', u'H27', u'H28', u'H29', u'H30', u'H31', u'H32', u'EXG7', u'EXG8', u'GSR1', u'GSR2', u'Erg1', u'Erg2', u'Resp', u'Plet', u'Temp']
# Processing events, external source: /imaging/deepthought/datasets/mpi2015/eeg/biosemi/P09_EEG_Data.mat
# 8662 events found
# Events id: [ 16  32  48 128 256 384 512]
# ['noise', 'Chim Chim Cheree with lyrics', 'Take Me Out To The Ballgame with lyrics', 'Jingle Bells with lyrics', 'Mary Had A Little Lamb with lyrics', 'Chim Chim Cheree without lyrics', 'Take Me Out To The Ballgame without lyrics', 'Jingle Bells without lyrics', 'Mary Had A Little Lamb without lyrics', 'Emperor Waltz', 'Harry Potter Theme', 'Star Wars Theme', 'Eine kleine Nachtmusik']
# block order:  [ 6  3 11  7  8  5  1  2  4  9 10 12]
# fixing label Take Me Out To The Ballgame without lyrics -> Take Me Out To The Ballgame without lyrics
# fixing label Jingle Bells with lyrics -> Jingle Bells with lyrics
# fixing label Jingle Bells with lyrics -> Star Wars Theme
# fixing label Jingle Bells without lyrics -> Jingle Bells without lyrics
# fixing label Mary Had A Little Lamb without lyrics -> Mary Had A Little Lamb without lyrics
# fixing label Chim Chim Cheree without lyrics -> Chim Chim Cheree without lyrics
# fixing label Chim Chim Cheree with lyrics -> Chim Chim Cheree with lyrics
# fixing label Take Me Out To The Ballgame with lyrics -> Take Me Out To The Ballgame with lyrics
# fixing label Mary Had A Little Lamb with lyrics -> Mary Had A Little Lamb with lyrics
# fixing label Mary Had A Little Lamb with lyrics -> Emperor Waltz
# fixing label Mary Had A Little Lamb with lyrics -> Harry Potter Theme
# fixing label Mary Had A Little Lamb with lyrics -> Eine kleine Nachtmusik
# block order:  [10  4  5  2  9  7  3 11  6 12  1  8]
# fixing label Mary Had A Little Lamb with lyrics -> Harry Potter Theme
# fixing label Mary Had A Little Lamb with lyrics -> Mary Had A Little Lamb with lyrics
# fixing label Chim Chim Cheree without lyrics -> Chim Chim Cheree without lyrics
# fixing label Take Me Out To The Ballgame with lyrics -> Take Me Out To The Ballgame with lyrics
# fixing label Take Me Out To The Ballgame with lyrics -> Emperor Waltz
# fixing label Jingle Bells without lyrics -> Jingle Bells without lyrics
# fixing label Jingle Bells with lyrics -> Jingle Bells with lyrics
# fixing label Jingle Bells with lyrics -> Star Wars Theme
# fixing label Take Me Out To The Ballgame without lyrics -> Take Me Out To The Ballgame without lyrics
# fixing label Take Me Out To The Ballgame without lyrics -> Eine kleine Nachtmusik
# fixing label Chim Chim Cheree with lyrics -> Chim Chim Cheree with lyrics
# fixing label Mary Had A Little Lamb without lyrics -> Mary Had A Little Lamb without lyrics
# block order:  [ 8 10 11  6  9  4  5  1  7  3  2 12]
# fixing label Mary Had A Little Lamb without lyrics -> Mary Had A Little Lamb without lyrics
# fixing label Mary Had A Little Lamb without lyrics -> Harry Potter Theme
# fixing label Mary Had A Little Lamb without lyrics -> Star Wars Theme
# fixing label Take Me Out To The Ballgame without lyrics -> Take Me Out To The Ballgame without lyrics
# fixing label Take Me Out To The Ballgame without lyrics -> Emperor Waltz
# fixing label Mary Had A Little Lamb with lyrics -> Mary Had A Little Lamb with lyrics
# fixing label Chim Chim Cheree without lyrics -> Chim Chim Cheree without lyrics
# fixing label Chim Chim Cheree with lyrics -> Chim Chim Cheree with lyrics
# fixing label Jingle Bells without lyrics -> Jingle Bells without lyrics
# fixing label Jingle Bells with lyrics -> Jingle Bells with lyrics
# fixing label Take Me Out To The Ballgame with lyrics -> Take Me Out To The Ballgame with lyrics
# fixing label Take Me Out To The Ballgame with lyrics -> Eine kleine Nachtmusik
# block order:  [ 4  9  2  6  5 11 10 12  1  7  8  3]
# fixing label Mary Had A Little Lamb with lyrics -> Mary Had A Little Lamb with lyrics
# fixing label Mary Had A Little Lamb with lyrics -> Emperor Waltz
# fixing label Take Me Out To The Ballgame with lyrics -> Take Me Out To The Ballgame with lyrics
# fixing label Take Me Out To The Ballgame without lyrics -> Take Me Out To The Ballgame without lyrics
# fixing label Chim Chim Cheree without lyrics -> Chim Chim Cheree without lyrics
# fixing label Chim Chim Cheree without lyrics -> Star Wars Theme
# fixing label Chim Chim Cheree without lyrics -> Harry Potter Theme
# fixing label Chim Chim Cheree without lyrics -> Eine kleine Nachtmusik
# fixing label Chim Chim Cheree with lyrics -> Chim Chim Cheree with lyrics
# fixing label Jingle Bells without lyrics -> Jingle Bells without lyrics
# fixing label Mary Had A Little Lamb without lyrics -> Mary Had A Little Lamb without lyrics
# fixing label Jingle Bells with lyrics -> Jingle Bells with lyrics
# block order:  [ 7  6 12  3 10  8 11  5  4  1  2  9]
# fixing label Jingle Bells without lyrics -> Jingle Bells without lyrics
# fixing label Take Me Out To The Ballgame without lyrics -> Take Me Out To The Ballgame without lyrics
# fixing label Take Me Out To The Ballgame without lyrics -> Eine kleine Nachtmusik
# fixing label Jingle Bells with lyrics -> Jingle Bells with lyrics
# fixing label Jingle Bells with lyrics -> Harry Potter Theme
# fixing label Mary Had A Little Lamb without lyrics -> Mary Had A Little Lamb without lyrics
# fixing label Mary Had A Little Lamb without lyrics -> Star Wars Theme
# fixing label Chim Chim Cheree without lyrics -> Chim Chim Cheree without lyrics
# fixing label Mary Had A Little Lamb with lyrics -> Mary Had A Little Lamb with lyrics
# fixing label Chim Chim Cheree with lyrics -> Chim Chim Cheree with lyrics
# fixing label Take Me Out To The Ballgame with lyrics -> Take Me Out To The Ballgame with lyrics
# fixing label Take Me Out To The Ballgame with lyrics -> Emperor Waltz
# block order:  [ 8  9 12  2 10  3  7  4  1 11  5  6]
# fixing label Mary Had A Little Lamb without lyrics -> Mary Had A Little Lamb without lyrics
# fixing label Mary Had A Little Lamb without lyrics -> Emperor Waltz
# fixing label Mary Had A Little Lamb without lyrics -> Eine kleine Nachtmusik
# fixing label Take Me Out To The Ballgame with lyrics -> Take Me Out To The Ballgame with lyrics
# fixing label Take Me Out To The Ballgame with lyrics -> Harry Potter Theme
# fixing label Jingle Bells with lyrics -> Jingle Bells with lyrics
# fixing label Jingle Bells without lyrics -> Jingle Bells without lyrics
# fixing label Mary Had A Little Lamb with lyrics -> Mary Had A Little Lamb with lyrics
# fixing label Chim Chim Cheree with lyrics -> Chim Chim Cheree with lyrics
# fixing label Chim Chim Cheree with lyrics -> Star Wars Theme
# fixing label Chim Chim Cheree without lyrics -> Chim Chim Cheree without lyrics
# fixing label Take Me Out To The Ballgame without lyrics -> Take Me Out To The Ballgame without lyrics
# block order:  [ 5  2  6  4  9  8 12 11  7  1 10  3]
# fixing label Chim Chim Cheree without lyrics -> Chim Chim Cheree without lyrics
# fixing label Take Me Out To The Ballgame with lyrics -> Take Me Out To The Ballgame with lyrics
# fixing label Take Me Out To The Ballgame without lyrics -> Take Me Out To The Ballgame without lyrics
# fixing label Mary Had A Little Lamb with lyrics -> Mary Had A Little Lamb with lyrics
# fixing label Mary Had A Little Lamb with lyrics -> Emperor Waltz
# fixing label Mary Had A Little Lamb without lyrics -> Mary Had A Little Lamb without lyrics
# fixing label Mary Had A Little Lamb without lyrics -> Eine kleine Nachtmusik
# fixing label Mary Had A Little Lamb without lyrics -> Star Wars Theme
# fixing label Jingle Bells without lyrics -> Jingle Bells without lyrics
# fixing label Chim Chim Cheree with lyrics -> Chim Chim Cheree with lyrics
# fixing label Chim Chim Cheree with lyrics -> Harry Potter Theme
# fixing label Jingle Bells with lyrics -> Jingle Bells with lyrics
# block order:  [ 8  7 12  2  5  9  6  4  3 10  1 11]
# fixing label Mary Had A Little Lamb without lyrics -> Mary Had A Little Lamb without lyrics
# fixing label Jingle Bells without lyrics -> Jingle Bells without lyrics
# fixing label Jingle Bells without lyrics -> Eine kleine Nachtmusik
# fixing label Take Me Out To The Ballgame with lyrics -> Take Me Out To The Ballgame with lyrics
# fixing label Chim Chim Cheree without lyrics -> Chim Chim Cheree without lyrics
# fixing label Chim Chim Cheree without lyrics -> Emperor Waltz
# fixing label Take Me Out To The Ballgame without lyrics -> Take Me Out To The Ballgame without lyrics
# fixing label Mary Had A Little Lamb with lyrics -> Mary Had A Little Lamb with lyrics
# fixing label Jingle Bells with lyrics -> Jingle Bells with lyrics
# fixing label Jingle Bells with lyrics -> Harry Potter Theme
# fixing label Chim Chim Cheree with lyrics -> Chim Chim Cheree with lyrics
# fixing label Chim Chim Cheree with lyrics -> Star Wars Theme
# block order:  [ 3  5  9 11  7  4  2  8  1 10 12  6]
# fixing label Jingle Bells with lyrics -> Jingle Bells with lyrics
# fixing label Chim Chim Cheree without lyrics -> Chim Chim Cheree without lyrics
# fixing label Chim Chim Cheree without lyrics -> Emperor Waltz
# fixing label Chim Chim Cheree without lyrics -> Star Wars Theme
# fixing label Jingle Bells without lyrics -> Jingle Bells without lyrics
# fixing label Mary Had A Little Lamb with lyrics -> Mary Had A Little Lamb with lyrics
# fixing label Take Me Out To The Ballgame with lyrics -> Take Me Out To The Ballgame with lyrics
# fixing label Mary Had A Little Lamb without lyrics -> Mary Had A Little Lamb without lyrics
# fixing label Chim Chim Cheree with lyrics -> Chim Chim Cheree with lyrics
# fixing label Chim Chim Cheree with lyrics -> Harry Potter Theme
# fixing label Chim Chim Cheree with lyrics -> Eine kleine Nachtmusik
# fixing label Take Me Out To The Ballgame without lyrics -> Take Me Out To The Ballgame without lyrics
# block order:  [11  4  7  5 12  3  9  1  2  8  6 10]
# fixing label Take Me Out To The Ballgame without lyrics -> Star Wars Theme
# fixing label Mary Had A Little Lamb with lyrics -> Mary Had A Little Lamb with lyrics
# fixing label Jingle Bells without lyrics -> Jingle Bells without lyrics
# fixing label Chim Chim Cheree without lyrics -> Chim Chim Cheree without lyrics
# fixing label Chim Chim Cheree without lyrics -> Eine kleine Nachtmusik
# fixing label Jingle Bells with lyrics -> Jingle Bells with lyrics
# fixing label Jingle Bells with lyrics -> Emperor Waltz
# fixing label Chim Chim Cheree with lyrics -> Chim Chim Cheree with lyrics
# fixing label Take Me Out To The Ballgame with lyrics -> Take Me Out To The Ballgame with lyrics
# fixing label Mary Had A Little Lamb without lyrics -> Mary Had A Little Lamb without lyrics
# fixing label Take Me Out To The Ballgame without lyrics -> Take Me Out To The Ballgame without lyrics
# fixing label Take Me Out To The Ballgame without lyrics -> Harry Potter Theme
# [(u'subject ID', u'09') (u'subject age', u'19')
#  (u'start time', u'20150225T165739572')
#  (u'FileOrder', [6, 3, 11, 7, 8, 5, 1, 2, 4, 9, 10, 12])
#  ('Take Me Out To The Ballgame without lyrics', u'20150225T170020802')
#  (u'cued imag', u'20150225T170035851')
#  (u'imag fix cross', u'20150225T170052209')
#  (u'noise', u'20150225T170102073')
#  ('Jingle Bells with lyrics', u'20150225T170109655')
#  (u'cued imag', u'20150225T170127131')
#  (u'imag fix cross', u'20150225T170145658')
#  (u'noise', u'20150225T170157687')
#  ('Star Wars Theme', u'20150225T170205272')
#  (u'cued imag', u'20150225T170222332')
#  (u'imag fix cross', u'20150225T170240423')
#  (u'noise', u'20150225T170252003')
#  ('Jingle Bells without lyrics', u'20150225T170259683')
#  (u'cued imag', u'20150225T170316215')
#  (u'imag fix cross', u'20150225T170334072')
#  (u'noise', u'20150225T170345437')
#  ('Mary Had A Little Lamb without lyrics', u'20150225T170353135')
#  (u'cued imag', u'20150225T170413813')
#  (u'imag fix cross', u'20150225T170435569')
#  (u'noise', u'20150225T170450829')
#  ('Chim Chim Cheree without lyrics', u'20150225T170458523')
#  (u'cued imag', u'20150225T170519092')
#  (u'imag fix cross', u'20150225T170541198')
#  (u'noise', u'20150225T170556792')
#  ('Chim Chim Cheree with lyrics', u'20150225T170604478')
#  (u'cued imag', u'20150225T170624635')
#  (u'imag fix cross', u'20150225T170646143')
#  (u'noise', u'20150225T170701155')
#  ('Take Me Out To The Ballgame with lyrics', u'20150225T170708833')
#  (u'cued imag', u'20150225T170723817')
#  (u'imag fix cross', u'20150225T170739892')
#  (u'noise', u'20150225T170749471')
#  ('Mary Had A Little Lamb with lyrics', u'20150225T170757164')
#  (u'cued imag', u'20150225T170817319')
#  (u'imag fix cross', u'20150225T170838472')
#  (u'noise', u'20150225T170853137') ('Emperor Waltz', u'20150225T170900713')
#  (u'cued imag', u'20150225T170916213')
#  (u'imag fix cross', u'20150225T170933087')
#  (u'noise', u'20150225T170943452')
#  ('Harry Potter Theme', u'20150225T170951057')
#  (u'cued imag', u'20150225T171014826')
#  (u'imag fix cross', u'20150225T171039433')
#  (u'noise', u'20150225T171057544')
#  ('Eine kleine Nachtmusik', u'20150225T171105125')
#  (u'cued imag', u'20150225T171120538')
#  (u'imag fix cross', u'20150225T171137313')
#  (u'noise', u'20150225T171147592')
#  (u'FileOrder', [10, 4, 5, 2, 9, 7, 3, 11, 6, 12, 1, 8])
#  ('Harry Potter Theme', u'20150225T171226631')
#  (u'cued imag', u'20150225T171250407')
#  (u'imag fix cross', u'20150225T171315014')
#  (u'noise', u'20150225T171333126')
#  ('Mary Had A Little Lamb with lyrics', u'20150225T171340811')
#  (u'cued imag', u'20150225T171400967')
#  (u'imag fix cross', u'20150225T171422126')
#  (u'noise', u'20150225T171436787')
#  ('Chim Chim Cheree without lyrics', u'20150225T171444482')
#  (u'cued imag', u'20150225T171505045')
#  (u'imag fix cross', u'20150225T171527138')
#  (u'noise', u'20150225T171542732')
#  ('Take Me Out To The Ballgame with lyrics', u'20150225T171550312')
#  (u'cued imag', u'20150225T171605200')
#  (u'imag fix cross', u'20150225T171621270')
#  (u'noise', u'20150225T171630850') ('Emperor Waltz', u'20150225T171638531')
#  (u'cued imag', u'20150225T171654028')
#  (u'imag fix cross', u'20150225T171710887')
#  (u'noise', u'20150225T171721250')
#  ('Jingle Bells without lyrics', u'20150225T171728931')
#  (u'cued imag', u'20150225T171745478')
#  (u'imag fix cross', u'20150225T171803337')
#  (u'noise', u'20150225T171814699')
#  ('Jingle Bells with lyrics', u'20150225T171822380')
#  (u'cued imag', u'20150225T171839960')
#  (u'imag fix cross', u'20150225T171858485')
#  (u'noise', u'20150225T171910514')
#  ('Star Wars Theme', u'20150225T171918094')
#  (u'cued imag', u'20150225T171935047')
#  (u'imag fix cross', u'20150225T171953134')
#  (u'noise', u'20150225T172004712')
#  ('Take Me Out To The Ballgame without lyrics', u'20150225T172012392')
#  (u'cued imag', u'20150225T172027373')
#  (u'imag fix cross', u'20150225T172043734')
#  (u'noise', u'20150225T172053597')
#  ('Eine kleine Nachtmusik', u'20150225T172101274')
#  (u'cued imag', u'20150225T172116674')
#  (u'imag fix cross', u'20150225T172133451')
#  (u'noise', u'20150225T172143730')
#  ('Chim Chim Cheree with lyrics', u'20150225T172151423')
#  (u'cued imag', u'20150225T172211571')
#  (u'imag fix cross', u'20150225T172233081')
#  (u'noise', u'20150225T172248094')
#  ('Mary Had A Little Lamb without lyrics', u'20150225T172255787')
#  (u'cued imag', u'20150225T172316452')
#  (u'imag fix cross', u'20150225T172338210')
#  (u'noise', u'20150225T172353471')
#  (u'FileOrder', [8, 10, 11, 6, 9, 4, 5, 1, 7, 3, 2, 12])
#  ('Mary Had A Little Lamb without lyrics', u'20150225T172421316')
#  (u'cued imag', u'20150225T172441889')
#  (u'imag fix cross', u'20150225T172503648')
#  (u'noise', u'20150225T172518910')
#  ('Harry Potter Theme', u'20150225T172526612')
#  (u'cued imag', u'20150225T172550386')
#  (u'imag fix cross', u'20150225T172614991')
#  (u'noise', u'20150225T172633103')
#  ('Star Wars Theme', u'20150225T172640789')
#  (u'cued imag', u'20150225T172657845')
#  (u'imag fix cross', u'20150225T172715938')
#  (u'noise', u'20150225T172727516')
#  ('Take Me Out To The Ballgame without lyrics', u'20150225T172735196')
#  (u'cued imag', u'20150225T172750080')
#  (u'imag fix cross', u'20150225T172806438')
#  (u'noise', u'20150225T172816300') ('Emperor Waltz', u'20150225T172823980')
#  (u'cued imag', u'20150225T172839478')
#  (u'imag fix cross', u'20150225T172856338')
#  (u'noise', u'20150225T172906701')
#  ('Mary Had A Little Lamb with lyrics', u'20150225T172914296')
#  (u'cued imag', u'20150225T172934444')
#  (u'imag fix cross', u'20150225T172955602')
#  (u'noise', u'20150225T173010264')
#  ('Chim Chim Cheree without lyrics', u'20150225T173017859')
#  (u'cued imag', u'20150225T173038522')
#  (u'imag fix cross', u'20150225T173100614')
#  (u'noise', u'20150225T173116210')
#  ('Chim Chim Cheree with lyrics', u'20150225T173123801')
#  (u'cued imag', u'20150225T173143951')
#  (u'imag fix cross', u'20150225T173205460')
#  (u'noise', u'20150225T173220472')
#  ('Jingle Bells without lyrics', u'20150225T173228151')
#  (u'cued imag', u'20150225T173244697')
#  (u'imag fix cross', u'20150225T173302558')
#  (u'noise', u'20150225T173313919')
#  ('Jingle Bells with lyrics', u'20150225T173321603')
#  (u'cued imag', u'20150225T173339177')
#  (u'imag fix cross', u'20150225T173357706')
#  (u'noise', u'20150225T173409735')
#  ('Take Me Out To The Ballgame with lyrics', u'20150225T173417422')
#  (u'cued imag', u'20150225T173432412')
#  (u'imag fix cross', u'20150225T173448489')
#  (u'noise', u'20150225T173458068')
#  ('Eine kleine Nachtmusik', u'20150225T173505649')
#  (u'cued imag', u'20150225T173521062')
#  (u'imag fix cross', u'20150225T173537839')
#  (u'noise', u'20150225T173548119')
#  (u'FileOrder', [4, 9, 2, 6, 5, 11, 10, 12, 1, 7, 8, 3])
#  ('Mary Had A Little Lamb with lyrics', u'20150225T173618586')
#  (u'cued imag', u'20150225T173638737')
#  (u'imag fix cross', u'20150225T173659895')
#  (u'noise', u'20150225T173714557') ('Emperor Waltz', u'20150225T173722239')
#  (u'cued imag', u'20150225T173737751')
#  (u'imag fix cross', u'20150225T173754611')
#  (u'noise', u'20150225T173804975')
#  ('Take Me Out To The Ballgame with lyrics', u'20150225T173812548')
#  (u'cued imag', u'20150225T173827436')
#  (u'imag fix cross', u'20150225T173843512')
#  (u'noise', u'20150225T173853092')
#  ('Take Me Out To The Ballgame without lyrics', u'20150225T173900769')
#  (u'cued imag', u'20150225T173915752')
#  (u'imag fix cross', u'20150225T173932113')
#  (u'noise', u'20150225T173941975')
#  ('Chim Chim Cheree without lyrics', u'20150225T173949571')
#  (u'cued imag', u'20150225T174010251')
#  (u'imag fix cross', u'20150225T174032342')
#  (u'noise', u'20150225T174047937')
#  ('Star Wars Theme', u'20150225T174055619')
#  (u'cued imag', u'20150225T174112680')
#  (u'imag fix cross', u'20150225T174130773')
#  (u'noise', u'20150225T174142353')
#  ('Harry Potter Theme', u'20150225T174149959')
#  (u'cued imag', u'20150225T174213728')
#  (u'imag fix cross', u'20150225T174238335')
#  (u'noise', u'20150225T174256446')
#  ('Eine kleine Nachtmusik', u'20150225T174304125')
#  (u'cued imag', u'20150225T174319538')
#  (u'imag fix cross', u'20150225T174336316')
#  (u'noise', u'20150225T174346595')
#  ('Chim Chim Cheree with lyrics', u'20150225T174354290')
#  (u'cued imag', u'20150225T174414455')
#  (u'imag fix cross', u'20150225T174435962')
#  (u'noise', u'20150225T174450976')
#  ('Jingle Bells without lyrics', u'20150225T174458652')
#  (u'cued imag', u'20150225T174515085')
#  (u'imag fix cross', u'20150225T174532944')
#  (u'noise', u'20150225T174544307')
#  ('Mary Had A Little Lamb without lyrics', u'20150225T174552002')
#  (u'cued imag', u'20150225T174612667')
#  (u'imag fix cross', u'20150225T174634424')
#  (u'noise', u'20150225T174649685')
#  ('Jingle Bells with lyrics', u'20150225T174657365')
#  (u'cued imag', u'20150225T174714947')
#  (u'imag fix cross', u'20150225T174733470')
#  (u'noise', u'20150225T174745499')
#  (u'FileOrder', [7, 6, 12, 3, 10, 8, 11, 5, 4, 1, 2, 9])
#  ('Jingle Bells without lyrics', u'20150225T174809722')
#  (u'cued imag', u'20150225T174826253')
#  (u'imag fix cross', u'20150225T174844114')
#  (u'noise', u'20150225T174855476')
#  ('Take Me Out To The Ballgame without lyrics', u'20150225T174903056')
#  (u'cued imag', u'20150225T174917955')
#  (u'imag fix cross', u'20150225T174934314')
#  (u'noise', u'20150225T174944177')
#  ('Eine kleine Nachtmusik', u'20150225T174951857')
#  (u'cued imag', u'20150225T175007271')
#  (u'imag fix cross', u'20150225T175024048')
#  (u'noise', u'20150225T175034327')
#  ('Jingle Bells with lyrics', u'20150225T175041904')
#  (u'cued imag', u'20150225T175059472')
#  (u'imag fix cross', u'20150225T175117997')
#  (u'noise', u'20150225T175130027')
#  ('Harry Potter Theme', u'20150225T175137626')
#  (u'cued imag', u'20150225T175201401')
#  (u'imag fix cross', u'20150225T175226008')
#  (u'noise', u'20150225T175244119')
#  ('Mary Had A Little Lamb without lyrics', u'20150225T175251812')
#  (u'cued imag', u'20150225T175312479')
#  (u'imag fix cross', u'20150225T175334235')
#  (u'noise', u'20150225T175349497')
#  ('Star Wars Theme', u'20150225T175357178')
#  (u'cued imag', u'20150225T175414241')
#  (u'imag fix cross', u'20150225T175432332')
#  (u'noise', u'20150225T175443914')
#  ('Chim Chim Cheree without lyrics', u'20150225T175451607')
#  (u'cued imag', u'20150225T175512270')
#  (u'imag fix cross', u'20150225T175534363')
#  (u'noise', u'20150225T175549957')
#  ('Mary Had A Little Lamb with lyrics', u'20150225T175557648')
#  (u'cued imag', u'20150225T175617701')
#  (u'imag fix cross', u'20150225T175638858')
#  (u'noise', u'20150225T175653521')
#  ('Chim Chim Cheree with lyrics', u'20150225T175701212')
#  (u'cued imag', u'20150225T175721264')
#  (u'imag fix cross', u'20150225T175742770')
#  (u'noise', u'20150225T175757782')
#  ('Take Me Out To The Ballgame with lyrics', u'20150225T175805361')
#  (u'cued imag', u'20150225T175820360')
#  (u'imag fix cross', u'20150225T175836436')
#  (u'noise', u'20150225T175846016') ('Emperor Waltz', u'20150225T175853696')
#  (u'cued imag', u'20150225T175909210')
#  (u'imag fix cross', u'20150225T175926070')
#  (u'noise', u'20150225T175936432')
#  (u'Beginning of Block 2', u'20150225T180106903')
#  (u'FileOrder', [8, 9, 12, 2, 10, 3, 7, 4, 1, 11, 5, 6])
#  ('Mary Had A Little Lamb without lyrics', u'20150225T180111434')
#  (u'keystroke', u'RightArrow') ('Emperor Waltz', u'20150225T180134444')
#  (u'keystroke', u'LeftArrow')
#  ('Eine kleine Nachtmusik', u'20150225T180151522')
#  (u'keystroke', u'LeftArrow')
#  ('Take Me Out To The Ballgame with lyrics', u'20150225T180207666')
#  (u'keystroke', u'RightArrow')
#  ('Harry Potter Theme', u'20150225T180223561') (u'keystroke', u'LeftArrow')
#  ('Jingle Bells with lyrics', u'20150225T180247519')
#  (u'keystroke', u'RightArrow')
#  ('Jingle Bells without lyrics', u'20150225T180305131')
#  (u'keystroke', u'RightArrow')
#  ('Mary Had A Little Lamb with lyrics', u'20150225T180322142')
#  (u'keystroke', u'RightArrow')
#  ('Chim Chim Cheree with lyrics', u'20150225T180342868')
#  (u'keystroke', u'RightArrow') ('Star Wars Theme', u'20150225T180403962')
#  (u'keystroke', u'RightArrow')
#  ('Chim Chim Cheree without lyrics', u'20150225T180421122')
#  (u'keystroke', u'RightArrow')
#  ('Take Me Out To The Ballgame without lyrics', u'20150225T180442515')
#  (u'keystroke', u'RightArrow')
#  (u'FileOrder', [5, 2, 6, 4, 9, 8, 12, 11, 7, 1, 10, 3])
#  ('Chim Chim Cheree without lyrics', u'20150225T180458194')
#  (u'keystroke', u'RightArrow')
#  ('Take Me Out To The Ballgame with lyrics', u'20150225T180519436')
#  (u'keystroke', u'RightArrow')
#  ('Take Me Out To The Ballgame without lyrics', u'20150225T180534998')
#  (u'keystroke', u'RightArrow')
#  ('Mary Had A Little Lamb with lyrics', u'20150225T180550560')
#  (u'keystroke', u'RightArrow') ('Emperor Waltz', u'20150225T180611953')
#  (u'keystroke', u'LeftArrow')
#  ('Mary Had A Little Lamb without lyrics', u'20150225T180627964')
#  (u'keystroke', u'RightArrow')
#  ('Eine kleine Nachtmusik', u'20150225T180649224')
#  (u'keystroke', u'LeftArrow') ('Star Wars Theme', u'20150225T180705285')
#  (u'keystroke', u'RightArrow')
#  ('Jingle Bells without lyrics', u'20150225T180722712')
#  (u'keystroke', u'RightArrow')
#  ('Chim Chim Cheree with lyrics', u'20150225T180739440')
#  (u'keystroke', u'RightArrow')
#  ('Harry Potter Theme', u'20150225T180800083')
#  (u'keystroke', u'RightArrow')
#  ('Jingle Bells with lyrics', u'20150225T180825108')
#  (u'keystroke', u'RightArrow')
#  (u'FileOrder', [8, 7, 12, 2, 5, 9, 6, 4, 3, 10, 1, 11])
#  ('Mary Had A Little Lamb without lyrics', u'20150225T180842770')
#  (u'keystroke', u'RightArrow')
#  ('Jingle Bells without lyrics', u'20150225T180903845')
#  (u'keystroke', u'LeftArrow')
#  ('Eine kleine Nachtmusik', u'20150225T180921890')
#  (u'keystroke', u'LeftArrow')
#  ('Take Me Out To The Ballgame with lyrics', u'20150225T180937485')
#  (u'keystroke', u'RightArrow')
#  ('Chim Chim Cheree without lyrics', u'20150225T180952963')
#  (u'keystroke', u'RightArrow') ('Emperor Waltz', u'20150225T181014406')
#  (u'keystroke', u'LeftArrow')
#  ('Take Me Out To The Ballgame without lyrics', u'20150225T181030534')
#  (u'keystroke', u'RightArrow')
#  ('Mary Had A Little Lamb with lyrics', u'20150225T181047245')
#  (u'keystroke', u'RightArrow')
#  ('Jingle Bells with lyrics', u'20150225T181108222')
#  (u'keystroke', u'RightArrow')
#  ('Harry Potter Theme', u'20150225T181125799')
#  (u'keystroke', u'RightArrow')
#  ('Chim Chim Cheree with lyrics', u'20150225T181149941')
#  (u'keystroke', u'RightArrow') ('Star Wars Theme', u'20150225T181211001')
#  (u'keystroke', u'RightArrow')
#  (u'FileOrder', [3, 5, 9, 11, 7, 4, 2, 8, 1, 10, 12, 6])
#  ('Jingle Bells with lyrics', u'20150225T181227962')
#  (u'keystroke', u'RightArrow')
#  ('Chim Chim Cheree without lyrics', u'20150225T181245507')
#  (u'keystroke', u'RightArrow') ('Emperor Waltz', u'20150225T181306866')
#  (u'keystroke', u'LeftArrow') ('Star Wars Theme', u'20150225T181322761')
#  (u'keystroke', u'RightArrow')
#  ('Jingle Bells without lyrics', u'20150225T181339872')
#  (u'keystroke', u'LeftArrow')
#  ('Mary Had A Little Lamb with lyrics', u'20150225T181357399')
#  (u'keystroke', u'RightArrow')
#  ('Take Me Out To The Ballgame with lyrics', u'20150225T181417659')
#  (u'keystroke', u'RightArrow')
#  ('Mary Had A Little Lamb without lyrics', u'20150225T181433238')
#  (u'keystroke', u'RightArrow')
#  ('Chim Chim Cheree with lyrics', u'20150225T181454031')
#  (u'keystroke', u'RightArrow')
#  ('Harry Potter Theme', u'20150225T181514557') (u'keystroke', u'LeftArrow')
#  ('Eine kleine Nachtmusik', u'20150225T181538200')
#  (u'keystroke', u'LeftArrow')
#  ('Take Me Out To The Ballgame without lyrics', u'20150225T181554094')
#  (u'keystroke', u'RightArrow')
#  (u'FileOrder', [11, 4, 7, 5, 12, 3, 9, 1, 2, 8, 6, 10])
#  ('Star Wars Theme', u'20150225T181609323') (u'keystroke', u'RightArrow')
#  ('Mary Had A Little Lamb with lyrics', u'20150225T181626917')
#  (u'keystroke', u'RightArrow')
#  ('Jingle Bells without lyrics', u'20150225T181647677')
#  (u'keystroke', u'RightArrow')
#  ('Chim Chim Cheree without lyrics', u'20150225T181704804')
#  (u'keystroke', u'RightArrow')
#  ('Eine kleine Nachtmusik', u'20150225T181725814')
#  (u'keystroke', u'LeftArrow')
#  ('Jingle Bells with lyrics', u'20150225T181741642')
#  (u'keystroke', u'RightArrow') ('Emperor Waltz', u'20150225T181758903')
#  (u'keystroke', u'LeftArrow')
#  ('Chim Chim Cheree with lyrics', u'20150225T181814798')
#  (u'keystroke', u'RightArrow')
#  ('Take Me Out To The Ballgame with lyrics', u'20150225T181835608')
#  (u'keystroke', u'RightArrow')
#  ('Mary Had A Little Lamb without lyrics', u'20150225T181850570')
#  (u'keystroke', u'RightArrow')
#  ('Take Me Out To The Ballgame without lyrics', u'20150225T181911312')
#  (u'keystroke', u'RightArrow')
#  ('Harry Potter Theme', u'20150225T181926508') (u'keystroke', u'LeftArrow')
#  (u'end time', u'20150225T181945919')]
# WARNING (deepthought.datasets.mpi2015.preprocessing.keystrokes): No key mapping defined for P09. Using default mapping.
# WARNING (deepthought.datasets.mpi2015.events): unsupported type: start time
# WARNING (deepthought.datasets.mpi2015.events): unsupported type: end time
# keystroke keys: set([u'LeftArrow', u'RightArrow']) mapping: {u'RightArrow': 1, u'LeftArrow': 0}
# Cropping raw inplace to 175.627s - 4942.336s
# Saving raw fif data to: /imaging/deepthought/datasets/mpi2015/eeg/mne/P09-raw.fif
# Loading raw fif data from: /imaging/deepthought/datasets/mpi2015/eeg/mne/P09-raw.fif
# Opening raw data file /imaging/deepthought/datasets/mpi2015/eeg/mne/P09-raw.fif...
# Isotrak not found
#     Range : 0 ... 2440555 =      0.000 ...  4766.709 secs
# Ready.
# Adding average EEG reference projection.
# 1 projection items deactivated
# Reading 0 ... 2440555  =      0.000 ...  4766.709 secs...
# [done]
# Applying channel montage: <Montage | 64channels - 64 Channels: Fp1, AF7, AF3 ...>
# Saving raw fif data to: /imaging/deepthought/datasets/mpi2015/eeg/mne/P09-raw.fif
# Imported <Raw  |  n_channels x n_times : 71 x 2440556>
# Metadata: <Info | 18 non-empty fields
#     bads : list | 0 items
#     buffer_size_sec : numpy.float64 | 10.0
#     ch_names : list | Fp1, AF7, AF3, F1, F3, F5, F7, FT7, FC5, FC3
#     chs : list | 71 items (EEG: 66, STIM: 1, EOG: 4)
#     comps : list | 0 items
#     custom_ref_applied : bool | False
#     events : list | 0 items
#     file_id : dict | 4 items
#     filename : str | /imaging/d.../P09-raw.fif
#     highpass : float | 0.0
#     hpi_meas : list | 0 items
#     hpi_results : list | 0 items
#     lowpass : float | 104.0
#     meas_date : numpy.ndarray | 2015-02-25 12:18:34
#     meas_id : dict | 4 items
#     nchan : int | 71
#     projs : list | Average EEG reference: off
#     sfreq : float | 512.0
#     acq_pars : NoneType
#     acq_stim : NoneType
#     ctf_head_t : NoneType
#     description : NoneType
#     dev_ctf_t : NoneType
#     dev_head_t : NoneType
#     dig : NoneType
#     experimenter : NoneType
#     hpi_subsystem : NoneType
#     line_freq : NoneType
#     proj_id : NoneType
#     proj_name : NoneType
#     subject_info : NoneType
# >
# Loading raw data for subject "P09" from /imaging/deepthought/datasets/mpi2015/eeg/mne/P09-raw.fif
# Referencing to mastoid channels: [u'EXG5', u'EXG6']
# Applying a custom EEG reference.
# Removing existing average EEG reference projection.

# %%
print pipeline.raw.info
# Out:
# <Info | 18 non-empty fields
#     bads : list | 0 items
#     buffer_size_sec : numpy.float64 | 10.0
#     ch_names : list | Fp1, AF7, AF3, F1, F3, F5, F7, FT7, FC5, FC3
#     chs : list | 69 items (EEG: 64, STIM: 1, EOG: 4)
#     comps : list | 0 items
#     custom_ref_applied : bool | True
#     events : list | 0 items
#     file_id : dict | 4 items
#     filename : str | /imaging/d.../P09-raw.fif
#     highpass : float | 0.0
#     hpi_meas : list | 0 items
#     hpi_results : list | 0 items
#     lowpass : float | 104.0
#     meas_date : numpy.ndarray | 2015-02-25 12:18:34
#     meas_id : dict | 4 items
#     nchan : int | 69
#     projs : list | 0 items
#     sfreq : float | 512.0
#     acq_pars : NoneType
#     acq_stim : NoneType
#     ctf_head_t : NoneType
#     description : NoneType
#     dev_ctf_t : NoneType
#     dev_head_t : NoneType
#     dig : NoneType
#     experimenter : NoneType
#     hpi_subsystem : NoneType
#     line_freq : NoneType
#     proj_id : NoneType
#     proj_name : NoneType
#     subject_info : NoneType
# >

# %% [markdown]
# # Reject Bad Channels

# %%
# switch to interactive GUI mode to scroll through data
# %matplotlib tk 
pipeline.plot_raw();
pass
# Out:
# scroll using cursor keys, click on channels to mark as "bad"

# %%
# switch back to inline mode
# %matplotlib inline

# %%
# pipeline.reset_bad_channels() # use this to reset the channel list if needed

# %%
# TODO: change these value manually
# If you would rather apply the bandpass filter first, continue until it is applied 
# and then come back to this cell
pipeline.mark_bad_channels(None, save_to_raw=False) # nothing to change, None will keep old values
# pipeline.mark_bad_channels(['P8', 'P10', 'T8'], save_to_raw=True)
# Out:
# The following channels have been marked as bad: []

# %%
pipeline.print_bad_channels()
# Out:
# bad channels: []

# %%
pipeline.interpolate_bad_channels() # Note: this will overwrite data
# Out:
# No bad channels that need to be interpolated.

# %% [markdown]
# # Check and Merge Trials

# %%
pipeline.check_trial_events()
# Out:
# 540 events found
# Events id: [  11   12   13   14   21   22   23   24   31   32   33   34   41   42   43
#    44  111  112  113  114  121  122  123  124  131  132  133  134  141  142
#   143  144  211  212  213  214  221  222  223  224  231  232  233  234  241
#   242  243  244 1000 1111 2000 2001]
# [[    512       0     121]
#  [    522       0    1000]
#  [   8193       0     122]
#  ...,
#  [2422535       0    2001]
#  [2430222       0     224]
#  [2430315       0    2000]]
# 1st event at  [ 1.]
# last event at  [ 4746.70898438]

# %%
pipeline.check_trial_audio_onset_merge(use_audio_onsets=True, verbose=None)
# Out:
# 540 events found
# Events id: [  11   12   13   14   21   22   23   24   31   32   33   34   41   42   43
#    44  111  112  113  114  121  122  123  124  131  132  133  134  141  142
#   143  144  211  212  213  214  221  222  223  224  231  232  233  234  241
#   242  243  244 1000 1111 2000 2001]

# %%
pipeline.merge_trial_and_audio_onsets()
# Out:
# 540 events found
# Events id: [  11   12   13   14   21   22   23   24   31   32   33   34   41   42   43
#    44  111  112  113  114  121  122  123  124  131  132  133  134  141  142
#   143  144  211  212  213  214  221  222  223  224  231  232  233  234  241
#   242  243  244 1000 1111 2000 2001]
# 360 events found
# Events id: [  11   12   13   14   21   22   23   24   31   32   33   34   41   42   43
#    44  111  112  113  114  121  122  123  124  131  132  133  134  141  142
#   143  144  211  212  213  214  221  222  223  224  231  232  233  234  241
#   242  243  244 1111 2000 2001]

# %% [markdown]
# # Check PSD and Channels

# %%
pipeline.check_psd()
pipeline.check_psd(fmax=35)
# line noise will probably be visible @ multiples of 60Hz

# %%
pipeline.check_channel(0)
# quite some drift and movement in the breaks
# Out:
# (2430828,)

# %% [markdown]
# # Bandpass Filtering

# %%
pipeline.bandpass_filter()
# Out:
# Band-pass filtering from 0.5 - 30 Hz
# [Parallel(n_jobs=4)]: Done   1 out of  64 | elapsed:    0.7s remaining:   43.4s
# [Parallel(n_jobs=4)]: Done  14 out of  64 | elapsed:    2.7s remaining:    9.7s
# [Parallel(n_jobs=4)]: Done  27 out of  64 | elapsed:    4.7s remaining:    6.5s
# [Parallel(n_jobs=4)]: Done  40 out of  64 | elapsed:    6.8s remaining:    4.1s
# [Parallel(n_jobs=4)]: Done  53 out of  64 | elapsed:    8.8s remaining:    1.8s
# [Parallel(n_jobs=4)]: Done  64 out of  64 | elapsed:   10.4s finished

# %%
# %matplotlib tk 
pipeline.plot_raw();
pass
# Out:
# scroll using cursor keys, click on channels to mark as "bad"

# %%
# %matplotlib inline

# %%
pipeline.check_channel(0)
# looks like we got rid of that drift - nice!
# what's that? eyeblinks?
# Out:
# (2430828,)

# %%
## check PSD again - after bandpass, before down-sampling
pipeline.check_psd()
pipeline.check_psd(fmax=35)
# 60Hz is still visible

# %% [markdown]
# # Beat and EOG Epoching

# %%
pipeline.generate_beat_events() # Note: this includes cue-beats !!!
pipeline.beat_epochs.average().plot();
# Out:
# Loading stimulus metadata from /imaging/deepthought/datasets/mpi2015/meta/Stimuli_Meta.v2.xlsx
# {1: 6, 2: 6, 3: 8, 4: 8, 11: 6, 12: 6, 13: 8, 14: 8, 21: 6, 22: 6, 23: 4, 24: 8}
# <Epochs  |  n_events : 8140 (all good), tmin : -0.2 (s), tmax : 0.8 (s), baseline : (None, 0)>

# %%
pipeline.find_eog_events()
# wow - that's a lot of blinking
# Out:
# EOG channel index for this subject is: [64 65 66 67]
# Filtering the data to remove DC offset to help distinguish blinks from saccades
# Now detecting blinks and generating corresponding events
# Number of EOG events detected : 719

# %% [markdown]
# # Down-Sampling

# %%
pipeline.downsample()
# Out:
#         from doc:
#         WARNING: The intended purpose of this function is primarily to speed
#                 up computations (e.g., projection calculation) when precise timing
#                 of events is not required, as downsampling raw data effectively
#                 jitters trigger timings. It is generally recommended not to epoch
#                 downsampled data, but instead epoch and then downsample, as epoching
#                 downsampled data jitters triggers.
#
#         NOTE: event onset collisions will be reported as warnings
#               in that case, it might be a good idea to pick either the trial onset or audio onset events
#               and delete the other ones before downsampling
#
# down-sampling raw and events stim channel ...
# saving events for stim channel "STI 014" (#68)
# 360 events found
# Events id: [  11   12   13   14   21   22   23   24   31   32   33   34   41   42   43
#    44  111  112  113  114  121  122  123  124  131  132  133  134  141  142
#   143  144  211  212  213  214  221  222  223  224  231  232  233  234  241
#   242  243  244 1111 2000 2001]
# resampling 69 channels...
# processing channel #0
# processing channel #1
# processing channel #2
# processing channel #3
# processing channel #4
# processing channel #5
# processing channel #6
# processing channel #7
# processing channel #8
# processing channel #9
# processing channel #10
# processing channel #11
# processing channel #12
# processing channel #13
# processing channel #14
# processing channel #15
# processing channel #16
# processing channel #17
# processing channel #18
# processing channel #19
# processing channel #20
# processing channel #21
# processing channel #22
# processing channel #23
# processing channel #24
# processing channel #25
# processing channel #26
# processing channel #27
# processing channel #28
# processing channel #29
# processing channel #30
# processing channel #31
# processing channel #32
# processing channel #33
# processing channel #34
# processing channel #35
# processing channel #36
# processing channel #37
# processing channel #38
# processing channel #39
# processing channel #40
# processing channel #41
# processing channel #42
# processing channel #43
# processing channel #44
# processing channel #45
# processing channel #46
# processing channel #47
# processing channel #48
# processing channel #49
# processing channel #50
# processing channel #51
# processing channel #52
# processing channel #53
# processing channel #54
# processing channel #55
# processing channel #56
# processing channel #57
# processing channel #58
# processing channel #59
# processing channel #60
# processing channel #61
# processing channel #62
# processing channel #63
# processing channel #64
# processing channel #65
# processing channel #66
# processing channel #67
# processing channel #68
# data shape after resampling: (69, 303854)
# restoring events for stim channel "STI 014" (#68)
# down-sampling epochs ...
# TODO: down-sampling events (not in stim channel) ...

# %%
## PSD after down-sampling:
pipeline.check_psd(fmax=35)
# looks less smooth than without down-sampling

# %%
# check events after after resampling -> should get the same result as above
pipeline.check_resampled_trial_events(plot=True, verbose=False)
# Out:
# 360 events found
# Events id: [  11   12   13   14   21   22   23   24   31   32   33   34   41   42   43
#    44  111  112  113  114  121  122  123  124  131  132  133  134  141  142
#   143  144  211  212  213  214  221  222  223  224  231  232  233  234  241
#   242  243  244 1111 2000 2001]
# event onset jitter (min, mean, max): -0.013671875 -0.00724283854167 0.0

# %% [markdown]
# # ICA

# %%
pipeline.compute_ica(verbose=True)
# Out:
# Fitting ICA to data using 64 channels.
# Please be patient, this may take some time
# Inferring max_pca_components from picks.
# Selection by explained variance: 63 components
# computing Extended Infomax ICA

# %%
# %matplotlib inline
pipeline.plot_ica_components() # static plot
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/colorbar.py:215: UserWarning: Use the colorbar set_ticks() method instead.
#   warnings.warn("Use the colorbar set_ticks() method instead.")
# /usr/local/lib/python2.7/dist-packages/mne-0.9.dev-py2.7.egg/mne/viz/utils.py:125: UserWarning: Matplotlib function 'tight_layout' is not supported by your backend: `module://IPython.kernel.zmq.pylab.backend_inline`. Skipping subpplot adjusment.
#   warn(msg % case)

# %%
pipeline.inspect_source_psd(1) # plot the PSD of an IC source to look for alpha activity
pipeline.inspect_source_psd(2)

# %%
pipeline.find_eog_artifact_sources(plot=True, verbose=False)
# Out:
# suggested EOG artifact channels:  [0, 1, 3, 6]
# EOG artifact component scores:  [ 0.41962239  0.17610312  0.39484017  0.13731637]

# %%
pipeline.auto_detect_artifact_components()
# Out:
#     Searching for artifacts...
#     found 1 artifact by skewness
#     found 1 artifact by kurtosis
#     found 1 artifact by variance
# Artifact indices found:
#     18, 8, 6
# Ready.
# merging [[0, 1, 3, 6], [18, 8, 6]]

# %%
pipeline.select_artifact_sources(selection='auto')
# Out:
# suggested channels to reject (selection="auto"):  [0, 1, 3, 6, 8, 18]
# To change the component selection, specify select=[...] (component numbers) or select=N (top-N) and run this command again!
# current selection: [0, 1, 3, 6, 8, 18]

# %%
pipeline.exclude_ica_components(selection=[0,1,3, 18]) # TODO: adapt selection list
# use cells below to decide, which components to reject, then come back to this cell
# Out:
# excluding ICA components:  [0, 1, 3, 18]

# %%
for ic in pipeline.suggested_artifact_components:
# for ic in pipeline.ica.exclude:
    pipeline.inspect_ica_component(ic, [0, 700])
    pipeline.inspect_source_epochs(ic, mode='beats', vmax=5)
    pipeline.inspect_source_epochs(ic, mode='eog', vmax=5)

# %%
# enable this for interactive mode
# %matplotlib tk

# pipeline.plot_sources(mode='raw')   # this may take a while
# pipeline.plot_sources(mode='beats')
pipeline.plot_sources(mode='eog');
# Out:
# NOTE: Plotting in non-interactive mode.

# %%
# switch back to non-interactive inline mode
# %matplotlib inline

# %%
pipeline.assess_unmixing_quality(verbose=False)
# Out:
# Assess impact on average EOG artifact:
# Assess cleaning of EOG epochs:
# Transforming to ICA space (63 components)
# Zeroing out 4 ICA components
# Inverse transforming to PCA space
# Reconstructing sensor space signals from 64 PCA components
# Assess impact on raw. Check the amplitudes do not change:
# Transforming to ICA space (63 components)
# Zeroing out 4 ICA components
# Inverse transforming to PCA space
# Reconstructing sensor space signals from 64 PCA components
# Assess impact on evoked. Check the amplitudes do not change:
# Transforming to ICA space (63 components)
# Zeroing out 4 ICA components
# Inverse transforming to PCA space
# Reconstructing sensor space signals from 64 PCA components

# %%
pipeline.save_ica('100p_64c') # save for later
# Out:
# Writing ica solution to /imaging/deepthought/datasets/mpi2015/eeg/mne/P09-100p_64c-ica.fif...

# %% [markdown]
# # Application Test

# %%
pipeline.load_ica('100p_64c')
# Out:
# Reading /imaging/deepthought/datasets/mpi2015/eeg/mne/P09-100p_64c-ica.fif ...
# Isotrak not found
# Now restoring ICA solution ...
# Ready.

# %%
raw = pipeline.ica.apply(pipeline.raw, exclude=(pipeline.ica.exclude), copy=False)
if len(raw.info['bads']) > 0:
    raw.interpolate_bads_eeg() # interpolate bad channels afterwards as they are not processed by the ICA

# %matplotlib tk 
pipeline.plot_raw();
pass
# Out:
# Transforming to ICA space (64 components)
# Zeroing out 5 ICA components
# Inverse transforming to PCA space
# Reconstructing sensor space signals from 64 PCA components
# scroll using cursor keys, click on channels to mark as "bad"
